# %% [markdown]
# <a href="https://colab.research.google.com/github/KodumuruRaja/Crash-Courses/blob/main/Pandas-(Data-Visualization-Crash-Course).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2019-06-07',periods=1000),columns=['value'])
ts=pd.Series(randn(1000),index=pd.date_range('2019-06-07',periods=1000))

# %%
df['value']=df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  0.402691
# 2019-06-08 -0.098926
# 2019-06-09  0.292985
# 2019-06-10  0.425835
# 2019-06-11 -0.127164

# %%
ts=ts.cumsum()
ts.head()
# Out:
# 2019-06-07    0.299313
# 2019-06-08   -0.001968
# 2019-06-09    0.625191
# 2019-06-10    0.444039
# 2019-06-11   -0.613600
# Freq: D, dtype: float64

# %%
type(df),type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot()

# %%
plt.plot(ts)

# %%
ts.plot(figsize=(10,5))

# %%
df.plot()

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot()

# %%
iris.plot(figsize=(15,8),title='Iris Dataset')

# %%
ax=iris.plot(figsize=(15,8),title='Iris Dataset')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
ts.plot(kind='bar')

# %%
df.iloc[0].plot(kind='bar')

# %%
iris.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df=iris.drop(['species'],axis=1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
titanic['pclass'].plot(kind='bar')

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0 -0.170834  0.617403  1.027996 -1.149676
# 1 -0.601731 -0.759715  0.790431  1.292609
# 2 -0.894254  0.787904  0.491650  0.600261
# 3  1.646456  1.208574  1.210770  0.482776
# 4 -1.026688 -0.229782 -1.218952 -0.131427

# %%
df.plot.bar()

# %%
titanic['pclass'].plot(kind='hist')

# %%
df.plot.bar(stacked=True)

# %%
df.plot(kind='bar',stacked=True)

# %%
df.plot.barh(stacked=True)

# %%
iris.plot.hist()

# %%
iris.plot(kind='hist',stacked=True)

# %%
iris.plot(kind='hist',stacked=True,bins=50)

# %%
iris.plot(kind='hist',stacked=True,bins=50,orientation='horizontal')

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True,bins=50)

# %%
df=iris.drop(['species'],axis=1)

# %%
df.diff()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             NaN          NaN           NaN          NaN
# 1            -0.2         -0.5           0.0          0.0
# 2            -0.2          0.2          -0.1          0.0
# 3            -0.1         -0.1           0.2          0.0
# 4             0.4          0.5          -0.1          0.0
# ..            ...          ...           ...          ...
# 145           0.0         -0.3          -0.5         -0.2
# 146          -0.4         -0.5          -0.2         -0.4
# 147           0.2          0.5           0.2          0.1
# 148          -0.3          0.4           0.2          0.3
# 149          -0.3         -0.4          -0.3         -0.5
#
# [150 rows x 4 columns]

# %%
df.diff().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f477871b160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f47786fab38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f47786aae80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4778669240>]],
#       dtype=object)

# %%
df.diff().hist(color='r',alpha=0.5,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4778553550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f477858ff60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4778548320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f47784f96a0>]],
#       dtype=object)

# %%
df.plot(kind='box',figsize=(10,10))

# %%
color={'boxes':'DarkGreen','whiskers':'r'}

# %%
df.plot(kind='box',figsize=(10,10),color=color)

# %%
df.plot(kind='box',figsize=(10,10),color=color,vert=False)

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %%
df.plot.scatter(x='sepal_length',y='petal_length')

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')

# %%
ax=df.plot.scatter(x='sepal_length',y='petal_length',label='Length')
df.plot.scatter(x='sepal_width',y='petal_width',label='width',ax=ax,color='r')

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=df['petal_width']*200)

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10)

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10, C='sepal_width')

# %%
d=df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie()

# %%
d.plot.pie(figsize=(10,10))

# %%
d=df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4777dc99e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4777c36748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4777be6940>],
#       dtype=object)

# %%
d.plot.pie(subplots=True,figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4777b709e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4777b3cbe0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4777aeee10>],
#       dtype=object)

# %%
d.plot.pie(subplots=True,figsize=(20,20),fontsize=16,autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4777a76f28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4777a4d0f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f47779fe320>],
#       dtype=object)

# %%
series=pd.Series([0.1]*4,index=['a','b','c','d'])
series.plot.pie()

# %%
series=pd.Series([0.2]*4,index=['a','b','c','d'])
series.plot.pie()

# %%
series=pd.Series([0.2]*4,index=['a','b','c','d'],name='Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(12,12))
plt.show()

# %%
scatter_matrix(df,figsize=(8,8),diagonal='kde')
plt.show()

# %%
scatter_matrix(df,figsize=(12,12),diagonal='kde',color='r')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df,'sepal_width')

# %%
ts.plot(style='r--',label='Series',legend=True)

# %%
df.plot(legend=False,figsize=(10,5))

# %%
df.plot(legend=False,figsize=(10,5),logy=True)

# %%
x=df.drop(['sepal_width','petal_width'],axis=1)

# %%
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y=df.drop(['sepal_length','petal_length'],axis=1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
x.plot(figsize=(16,5))
y.plot(figsize=(16,5),secondary_y=True)

# %%
ax=x.plot(figsize=(16,5))
y.plot(figsize=(16,5),secondary_y=True,ax=ax)

# %%
ax=x.plot()
y.plot(figsize=(16,10),secondary_y=True,ax=ax)

# %%
x.plot(figsize=(10,5),x_compat=True)

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f47766c09b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4776690630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4776643860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f47765f5a90>],
#       dtype=object)

# %%
df.plot(subplots=True,sharex=False)
plt.tight_layout()

# %%
df.plot(subplots=True,sharex=False,layout=(2,2))
plt.tight_layout()

# %%
df.plot(subplots=True,sharex=False,layout=(2,2),figsize=(16,8))
plt.tight_layout()

# %%
df.plot(subplots=True,sharex=False,layout=(2,3),figsize=(16,8))
plt.tight_layout()

# %%
df.plot(subplots=True,sharex=False,layout=(4,1),figsize=(16,8))
plt.tight_layout()
